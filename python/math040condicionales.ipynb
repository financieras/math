# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/math/blob/main/python/math040condicionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Condicionales `if`
# Se analiza un condición y según sera verdadera (True) o falsa (Fasle) se actúa de una o de otra manera.

# %%
edad = 12

if edad >= 18:
    print("Puede obtener el permiso de conducir clase B")
else:
    print("Usted aún no tiene edad para obtener el permiso B")

print("Fin del programa")
# Out:
# Usted aún no tiene edad para obtener el permiso B
# Fin del programa

# %% [markdown]
# ## Condicionales múltiples
# ```python
# if <condición 1>:
#     <código>
# elif <condición 2>:
#     <código>
# elif <condición 3>:
#     <código>
# else:
#     <código>
# ```

# %%
edad = 8
if edad >= 18:
    print('Eres mayor de edad.')
elif edad >= 13:
    print('Eres un adolescente.')
else:
    print('Eres un niño.')
# Out:
# Eres un niño.

# %%
ciudades =["Roma", "Londres", "París", "Madrid", "Berlín"]
city = "París"

if city in ciudades:
    print(f"{city} si se encuentra en la lista de ciudades.")
else:
    print(f'{city} no se encuentra en la lista de ciudades.')
# Out:
# París si se encuentra en la lista de ciudades.
